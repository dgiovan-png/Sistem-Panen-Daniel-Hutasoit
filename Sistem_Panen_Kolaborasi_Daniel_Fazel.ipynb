# %% [markdown]
# <a href="https://colab.research.google.com/github/dgiovan-png/Sistem-Panen-Daniel-Hutasoit/blob/feature-input-fazel/Sistem_Panen_Kolaborasi_Daniel_Fazel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.makedirs('sistem-panen', exist_ok=True)
# %cd sistem-panen

# Inisialisasi git lokal
# !git init

# Buat dan pindah ke branch 'feature-laporan'
# !git checkout -b feature-laporan

# %%
# %%writefile -a sistem_panen.py

def cetak_laporan(data_panen, total_harga):
    print("\n=== LAPORAN HASIL PANEN ===")
    print(f"Petani    : {data_panen['petani']}")
    print(f"Komoditas : {data_panen['komoditas']}")
    print(f"Berat     : {data_panen['berat']} kg")
    print(f"Total     : Rp {total_harga:,.0f}")

# %%
# !git add sistem_panen.py
# !git commit -m "Add: Tambah fungsi cetak laporan oleh Anggota B"
