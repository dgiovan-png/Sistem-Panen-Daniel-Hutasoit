# %% [markdown]
# <a href="https://colab.research.google.com/github/dgiovan-png/Sistem-Panen-Daniel-Hutasoit/blob/feature-input/Sistem_Panen_Kolaborasi_Daniel_Fazel_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.makedirs('sistem-panen', exist_ok=True)
# %cd sistem-panen

# Inisialisasi git lokal jika belum
# !git init

# Buat dan pindah ke branch 'feature-input'
# !git checkout -b feature-input
# Out:
# /content/sistem-panen
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/sistem-panen/.git/
# Switched to a new branch 'feature-input'

# %%
# %%writefile -a sistem_panen.py

def input_data_panen():
    nama_petani = input("Nama Petani: ")
    komoditas = input("Jenis Komoditas: ")
    berat = float(input("Berat Panen (kg): "))
    return {"petani": nama_petani, "komoditas": komoditas, "berat": berat}
# Out:
# Writing sistem_panen.py

# %%
# !git add sistem_panen.py
# !git commit -m "Add: Tambah fungsi input data panen oleh Anggota A"
