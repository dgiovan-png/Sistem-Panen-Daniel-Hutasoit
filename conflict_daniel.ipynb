# %% [markdown]
# <a href="https://colab.research.google.com/github/dgiovan-png/Sistem-Panen-Daniel-Hutasoit/blob/conflict-daniel/conflict_daniel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git checkout -b conflict-daniel

# %%
# %%writefile sistem_panen.py
def hitung_total_panen(berat_kg):
    harga_per_kg = 18000
    return berat_kg * harga_per_kg

# %%
# !git add sistem_panen.py
# !git commit -m "Conflict: Daniel mengubah harga panen ke 18000"
